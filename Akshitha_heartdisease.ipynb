# %% [markdown]
# <a href="https://colab.research.google.com/github/rangaakshitha/HeartAttack_Prediction/blob/main/Akshitha_heartdisease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing the Libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px

# %% [markdown]
# # **Importing the dataset**

# %%
data=pd.read_csv("heart.csv")

# %% [markdown]
# # **Exploratory data Analysis**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  1190 non-null   int64
#  1   sex                  1190 non-null   int64
#  2   chest pain type      1190 non-null   int64
#  3   resting bp s         1190 non-null   int64
#  4   cholesterol          1190 non-null   int64
#  5   fasting blood sugar  1190 non-null   int64
#  6   resting ecg          1190 non-null   int64
#  7   max heart rate       1190 non-null   int64
#  8   exercise angina      1190 non-null   int64
#  9   oldpeak              1190 non-null   float64
#  10  ST slope             1190 non-null   int64
#  11  target               1190 non-null   int64
# dtypes: float64(1), int64(11)
# memory usage: 111.7 KB

# %%
data.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
data.tail()
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 1185   45    1                1           110          264
# 1186   68    1                4           144          193
# 1187   57    1                4           130          131
# 1188   57    0                2           130          236
# 1189   38    1                3           138          175
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 1185                    0            0             132                0
# 1186                    1            0             141                0
# 1187                    0            0             115                1
# 1188                    0            2             174                0
# 1189                    0            0             173                0
#
#       oldpeak  ST slope  target
# 1185      1.2         2       1
# 1186      3.4         2       1
# 1187      1.2         2       1
# 1188      0.0         2       1
# ...

# %%
data.columns
# Out:
# Index(['age', 'sex', 'chest pain type', 'resting bp s', 'cholesterol',
#        'fasting blood sugar', 'resting ecg', 'max heart rate',
#        'exercise angina', 'oldpeak', 'ST slope', 'target'],
#       dtype='object')

# %%
data.dtypes
# Out:
# age                      int64
# sex                      int64
# chest pain type          int64
# resting bp s             int64
# cholesterol              int64
# fasting blood sugar      int64
# resting ecg              int64
# max heart rate           int64
# exercise angina          int64
# oldpeak                float64
# ST slope                 int64
# target                   int64
# dtype: object

# %%
data.describe()
# Out:
#                age          sex  chest pain type  resting bp s  cholesterol  \
# count  1190.000000  1190.000000      1190.000000   1190.000000  1190.000000
# mean     53.720168     0.763866         3.232773    132.153782   210.363866
# std       9.358203     0.424884         0.935480     18.368823   101.420489
# min      28.000000     0.000000         1.000000      0.000000     0.000000
# 25%      47.000000     1.000000         3.000000    120.000000   188.000000
# 50%      54.000000     1.000000         4.000000    130.000000   229.000000
# 75%      60.000000     1.000000         4.000000    140.000000   269.750000
# max      77.000000     1.000000         4.000000    200.000000   603.000000
#
#        fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# count          1190.000000  1190.000000     1190.000000      1190.000000
# mean              0.213445     0.698319      139.732773         0.387395
# ...

# %%
data.isnull().sum()
# Out:
# age                    0
# sex                    0
# chest pain type        0
# resting bp s           0
# cholesterol            0
# fasting blood sugar    0
# resting ecg            0
# max heart rate         0
# exercise angina        0
# oldpeak                0
# ST slope               0
# target                 0
# dtype: int64

# %% [markdown]
# # **Data Wrangling**

# %% [markdown]
# **Detecting and dropping duplicates**

# %%
data.duplicated().sum()
# Out:
# 272

# %%
data.drop_duplicates(inplace=True)
data
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 0      40    1                2           140          289
# 1      49    0                3           160          180
# 2      37    1                2           130          283
# 3      48    0                4           138          214
# 4      54    1                3           150          195
# ...   ...  ...              ...           ...          ...
# 1185   45    1                1           110          264
# 1186   68    1                4           144          193
# 1187   57    1                4           130          131
# 1188   57    0                2           130          236
# 1189   38    1                3           138          175
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0             172                0
# 1                       0            0             156                0
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.count()
# Out:
# age                    918
# sex                    918
# chest pain type        918
# resting bp s           918
# cholesterol            918
# fasting blood sugar    918
# resting ecg            918
# max heart rate         918
# exercise angina        918
# oldpeak                918
# ST slope               918
# target                 918
# dtype: int64

# %% [markdown]
# **Dropping the missing values**

# %%
data.dropna(inplace=True)
data
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 0      40    1                2           140          289
# 1      49    0                3           160          180
# 2      37    1                2           130          283
# 3      48    0                4           138          214
# 4      54    1                3           150          195
# ...   ...  ...              ...           ...          ...
# 1185   45    1                1           110          264
# 1186   68    1                4           144          193
# 1187   57    1                4           130          131
# 1188   57    0                2           130          236
# 1189   38    1                3           138          175
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0             172                0
# 1                       0            0             156                0
# ...

# %% [markdown]
# **Detecting the outliners**

# %%
plt.figure(figsize = (12,12))
for i in range(len(data.columns)):
    plt.subplot(4,4,i+1)
    sns.boxplot(data[data.columns[i]])
plt.show()

# %% [markdown]
# # **Data Visualization**

# %%
sns.set(style="whitegrid")
fig,axes=plt.subplots(4,3,figsize=(18,16))
fig.suptitle("Distribution of each feature",fontsize=18)
for i,col in enumerate(data.columns):
  ax=axes[i//3,i%3]
  if data[col].nunique()<10:
    sns.countplot(x=col,hue=col,data=data,ax=ax,palette="viridis",legend=False)
    ax.set_ylabel("Count")
  else:
    sns.histplot(data[col],bins=20,kde=True,ax=ax,color="skyblue")
  ax.set_title(f'Distribution of {col}')
plt.tight_layout(rect=[0,0,1,0.96])

# %%
labels = data['target'].value_counts().index.to_list()
sizes = data['target'].value_counts().to_list()
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.axis('equal')
plt.title('Pie Chart of Target')
plt.show()

# %% [markdown]
# # **Numeric feature Analysis**

# %%
numeric_list = ["age", "resting bp s","cholesterol","max heart rate","oldpeak","target"]

# %%
data_numeric = data.loc[:, numeric_list]
sns.pairplot(data_numeric, hue = "target", diag_kind = "kde")
plt.show()

# %%
data.corr() #used to compute pairwise correlation of columns, excluding null values
# Out:
#                           age       sex  chest pain type  resting bp s  \
# age                  1.000000  0.055750         0.165896      0.254399
# sex                  0.055750  1.000000         0.168254      0.005133
# chest pain type      0.165896  0.168254         1.000000      0.022168
# resting bp s         0.254399  0.005133         0.022168      1.000000
# cholesterol         -0.095282 -0.200092        -0.136139      0.100893
# fasting blood sugar  0.198039  0.120076         0.116703      0.070193
# resting ecg          0.213152 -0.018343         0.031383      0.097661
# max heart rate      -0.382045 -0.189186        -0.343654     -0.112135
# exercise angina      0.215793  0.190664         0.416625      0.155101
# oldpeak              0.258612  0.105734         0.245027      0.164803
# ST slope             0.261760  0.148282         0.317256      0.071477
# target               0.282039  0.305445         0.471354      0.107589
#
# ...

# %%
plt.figure(figsize=(12,8))
c=data.corr()
sns.heatmap(c,annot=True,fmt=".2f",cmap="coolwarm",square=True)
plt.title("Correlation Heatmap of Features",fontsize=16)
plt.show()

# %%
data.corr()['target']
# Out:
# age                    0.282039
# sex                    0.305445
# chest pain type        0.471354
# resting bp s           0.107589
# cholesterol           -0.232741
# fasting blood sugar    0.267291
# resting ecg            0.061011
# max heart rate        -0.400421
# exercise angina        0.494282
# oldpeak                0.403951
# ST slope               0.553461
# target                 1.000000
# Name: target, dtype: float64

# %%
data.corr()['target'].plot(kind='bar') #used to compute pairwise correlation of columns, excluding null values and representing with bar plot
# Out:
# <Axes: >

# %% [markdown]
# # **Splitting the dataset into the Training set and Test set**

# %%
from sklearn.model_selection import train_test_split

predictors = data.drop("target",axis=1)
target = data["target"]

X_train,X_test,Y_train,Y_test = train_test_split(predictors,target,test_size=0.20,random_state=0)

# %%
X_train.shape
# Out:
# (734, 11)

# %%
X_test.shape
# Out:
# (184, 11)

# %%
Y_train.shape
# Out:
# (734,)

# %%
Y_test.shape
# Out:
# (184,)

# %% [markdown]
# # **Feature Scaling**

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %% [markdown]
# # **Model Fitting**

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## **Logistic Regression**

# %% [markdown]
# **Training the Logistic Regression model on the Training set**

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression(random_state=0)
classifier.fit(X_train,Y_train)
# Out:
# LogisticRegression(random_state=0)

# %% [markdown]
# **Predicting the Test set results**

# %%
y_pred=classifier.predict(X_test)
print(np.concatenate([y_pred.reshape(len(y_pred),1),Y_test.values.reshape(len(Y_test),1)],1))

# %% [markdown]
# **Confusion Matrix**

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(Y_test,y_pred)
print(cm)
# Out:
# [[59 18]
#  [13 94]]

# %% [markdown]
# **Accuracy**

# %%
score_lr = round(accuracy_score(y_pred,Y_test)*100,2)

print("The accuracy score achieved using Logistic Regression is: "+str(score_lr)+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 83.15 %

# %% [markdown]
# ## **Support Vector Machine(SVM)**

# %% [markdown]
# **Training the SVM model on the Training set**

# %%
from sklearn.svm import SVC
classifier=SVC(kernel='linear',random_state=0)
classifier.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %% [markdown]
# **Predicting the Test set results**

# %%
y_pred=classifier.predict(X_test)
print(np.concatenate([y_pred.reshape(len(y_pred),1),Y_test.values.reshape(len(Y_test),1)],1))

# %% [markdown]
# **Confusion Matrix**

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,y_pred)
print(cm)
# Out:
# [[62 15]
#  [13 94]]

# %% [markdown]
# **Accuracy**

# %%
score_svm = round(accuracy_score(y_pred,Y_test)*100,2)

print("The accuracy score achieved using Linear SVM is: "+str(score_svm)+" %")
# Out:
# The accuracy score achieved using Linear SVM is: 84.78 %

# %% [markdown]
# ## **K-Nearest Neighbors (K-NN)**

# %% [markdown]
# **Training the K-NN model on the Training set**

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=5,metric='minkowski',p=2)
classifier.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
#  **Predicting the Test set results**

# %%
y_pred=classifier.predict(X_test)
print(np.concatenate([y_pred.reshape(len(y_pred),1),Y_test.values.reshape(len(Y_test),1)],1))

# %% [markdown]
# **Confusion Matrix**

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,y_pred)
print(cm)
# Out:
# [[63 14]
#  [14 93]]

# %% [markdown]
# **Accuracy**

# %%
score_knn = round(accuracy_score(y_pred,Y_test)*100,2)

print("The accuracy score achieved using KNN is: "+str(score_knn)+" %")
# Out:
# The accuracy score achieved using KNN is: 84.78 %

# %% [markdown]
# ## **Navie Bayes**

# %% [markdown]
# **Training the Navie Bayes model on the Training set**

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

nb.fit(X_train,Y_train)
# Out:
# GaussianNB()

# %% [markdown]
# **Predicting the Test set results**

# %%
y_pred=classifier.predict(X_test)
print(np.concatenate([y_pred.reshape(len(y_pred),1),Y_test.values.reshape(len(Y_test),1)],1))

# %% [markdown]
# **Confusion Matrix**

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,y_pred)
print(cm)
# Out:
# [[63 14]
#  [14 93]]

# %% [markdown]
# **Accuracy**

# %%
score_nb = round(accuracy_score(y_pred,Y_test)*100,2)

print("The accuracy score achieved using Naive Bayes is: "+str(score_nb)+" %")
# Out:
# The accuracy score achieved using Naive Bayes is: 84.78 %

# %% [markdown]
# ## **Decision Tree**

# %% [markdown]
# **Training the Decision Tree model on the Training set**

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion='entropy', random_state=0)
classifier.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %% [markdown]
# **Predicting the Test set results**

# %%
y_pred = classifier.predict(X_test)
print(np.concatenate([y_pred.reshape(len(y_pred), 1), Y_test.values.reshape(len(Y_test), 1)], 1))

# %% [markdown]
# **Confusion Matrix**

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, y_pred)
print(cm)
# Out:
# [[66 11]
#  [23 84]]

# %% [markdown]
# **Accuracy**

# %%
score_dt = round(accuracy_score(y_pred, Y_test) * 100, 2)

print("The accuracy score achieved using Decision Tree is: " + str(score_dt) + " %")
# Out:
# The accuracy score achieved using Decision Tree is: 81.52 %

# %% [markdown]
# ## **Random Forest**

# %% [markdown]
# **Training the Random Forest model on the Training set**

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=10, criterion='entropy', random_state=0)
classifier.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %% [markdown]
# **Predicting the Test set results**

# %%
y_pred = classifier.predict(X_test)
print(np.concatenate([y_pred.reshape(len(y_pred), 1), Y_test.values.reshape(len(Y_test), 1)], 1))

# %% [markdown]
# **Confusion Matrix**

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, y_pred)
print(cm)
# Out:
# [[64 13]
#  [16 91]]

# %% [markdown]
# **Accuracy**

# %%
score_rf = round(accuracy_score(y_pred, Y_test) * 100, 2)

print("The accuracy score achieved using Random Forest is: " + str(score_rf) + " %")
# Out:
# The accuracy score achieved using Random Forest is: 84.24 %

# %% [markdown]
# # **Output and Final scores**

# %%
scores = [score_lr,score_svm,score_knn,score_nb,score_dt,score_rf]
algorithms = [ "Logistic Regression","Support Vector Machine","K-Nearest Neighbors","Naive Bayes","Decision Tree","Random Forest" ]

for i in range(len(algorithms)):

    print("The accuracy score achieved using "+algorithms[i]+" is: "+str(scores[i])+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 83.15 %
# The accuracy score achieved using Support Vector Machine is: 84.78 %
# The accuracy score achieved using K-Nearest Neighbors is: 84.78 %
# The accuracy score achieved using Naive Bayes is: 84.78 %
# The accuracy score achieved using Decision Tree is: 81.52 %
# The accuracy score achieved using Random Forest is: 84.24 %

# %%
sns.set(rc={'figure.figsize':(15,8)})
plt.xlabel("Algorithms")
plt.ylabel("Accuracy score")
sns.barplot(x=algorithms, y=scores)
# Out:
# <Axes: xlabel='Algorithms', ylabel='Accuracy score'>

# %% [markdown]
# # **Deployment**

# %% [markdown]
# **Super Vector Machine has good result**

# %%
import pandas as pd
from sklearn.svm import SVC

# Convert X_train to a pandas DataFrame if it's a NumPy array
if isinstance(X_train, np.ndarray):
    # Assuming 'data' is your original data and has column names
    X_train = pd.DataFrame(X_train, columns=data.columns[:-1]) # Use data.columns[:-1] instead of X.columns, assuming the last column is the target
classifier=SVC(kernel='linear',random_state=0)
classifier.fit(X_train,Y_train)

input_data = (50, 0, 0, 90, 80, 0, 0, 0, 1, 0, 2)

# Use data.columns[:-1] for consistency and ensure columns match
input_df = pd.DataFrame([input_data], columns=data.columns[:-1])

prediction =classifier.predict(input_df)

if prediction == 1:
    print("The patient seems to have heart attack \n\nIf the person have any Chest Pain,Upper Body Pain,Shortness of Breath or fainting SymptomsSome common medications used in emergency situations include:\n")

    print("Aspirin: Chewing a tablet of aspirin (usually 325 mg) can help prevent blood clots from worsening the heart attack.\n")

    print("Nitroglycerin: Available in tablet, spray, or patch form, nitroglycerin helps dilate blood vessels and improve blood flow to the heart.\n")

    print("Clopidogrel (Plavix): This antiplatelet medication helps prevent new clots from forming and is sometimes given alongside aspirin.\n")

    print("Beta-blockers: Medications like metoprolol can reduce the heart's workload and improve survival rates.\n")

    print("Statins: High-dose statins, such as atorvastatin, might be given to lower cholesterol levels and stabilize plaque.\n")

    print("Morphine: For pain relief and to reduce the heart's workload, though its use is more selective.\n")

    print("These medications are typically administered under medical supervision, and it is crucial to call emergency services immediately if a heart attack is suspected.\n")

    print("Visit a near by Cardiologist as soon as possible.")

else:
    print("The patient seems to be normal ")
# Out:
# The patient seems to be normal

# %%
import pandas as pd
from sklearn.svm import SVC

# Convert X_train to a pandas DataFrame if it's a NumPy array
if isinstance(X_train, np.ndarray):
    # Assuming 'data' is your original data and has column names
    X_train = pd.DataFrame(X_train, columns=data.columns[:-1]) # Use data.columns[:-1] instead of X.columns, assuming the last column is the target
classifier=SVC(kernel='linear',random_state=0)
classifier.fit(X_train,Y_train)

input_data = (63, 3, 145, 233, 150, 2.3, 0, 0, 2, 1, 3)

# Use data.columns[:-1] for consistency and ensure columns match
input_df = pd.DataFrame([input_data], columns=data.columns[:-1])

prediction =classifier.predict(input_df)

if prediction == 1:
    print("The patient seems to have heart attack \n\nIf the person have any Chest Pain,Upper Body Pain,Shortness of Breath or fainting SymptomsSome common medications used in emergency situations include:\n")

    print("Aspirin: Chewing a tablet of aspirin (usually 325 mg) can help prevent blood clots from worsening the heart attack.\n")

    print("Nitroglycerin: Available in tablet, spray, or patch form, nitroglycerin helps dilate blood vessels and improve blood flow to the heart.\n")

    print("Clopidogrel (Plavix): This antiplatelet medication helps prevent new clots from forming and is sometimes given alongside aspirin.\n")

    print("Beta-blockers: Medications like metoprolol can reduce the heart's workload and improve survival rates.\n")

    print("Statins: High-dose statins, such as atorvastatin, might be given to lower cholesterol levels and stabilize plaque.\n")

    print("Morphine: For pain relief and to reduce the heart's workload, though its use is more selective.\n")

    print("These medications are typically administered under medical supervision, and it is crucial to call emergency services immediately if a heart attack is suspected.\n")

    print("Visit a near by Cardiologist as soon as possible.")

else:
    print("The patient seems to be normal ")
# Out:
# The patient seems to have heart attack
#
# If the person have any Chest Pain,Upper Body Pain,Shortness of Breath or fainting SymptomsSome common medications used in emergency situations include:
#
# Aspirin: Chewing a tablet of aspirin (usually 325 mg) can help prevent blood clots from worsening the heart attack.
#
# Nitroglycerin: Available in tablet, spray, or patch form, nitroglycerin helps dilate blood vessels and improve blood flow to the heart.
#
# Clopidogrel (Plavix): This antiplatelet medication helps prevent new clots from forming and is sometimes given alongside aspirin.
#
# Beta-blockers: Medications like metoprolol can reduce the heart's workload and improve survival rates.
#
# Statins: High-dose statins, such as atorvastatin, might be given to lower cholesterol levels and stabilize plaque.
#
# Morphine: For pain relief and to reduce the heart's workload, though its use is more selective.
#
# ...

# %% [markdown]
# **Dataset**

# %% [markdown]
# https://www.kaggle.com/datasets/mexwell/heart-disease-dataset?select=heart_statlog_cleveland_hungary_final.csv
